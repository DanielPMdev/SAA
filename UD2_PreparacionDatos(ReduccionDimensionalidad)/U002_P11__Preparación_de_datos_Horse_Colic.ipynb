# %% [markdown]
# # Horse Colic Dataset:
# ## Can you predict the life or death of a horse?
# https://www.kaggle.com/uciml/horse-colic

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
dataset = pd.read_csv('/content/drive/MyDrive/SAA/data_folder/horse.csv', header = 0)
dataset.head()
# Out:
#   surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0      no  adult           530101         38.5   66.0              28.0
# 1     yes  adult           534817         39.2   88.0              20.0
# 2      no  adult           530334         38.3   40.0              24.0
# 3     yes  young          5290409         39.1  164.0              84.0
# 4      no  adult           530255         37.3  104.0              35.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0                cool          reduced             NaN            more_3_sec
# 1                 NaN              NaN   pale_cyanotic            less_3_sec
# 2              normal           normal       pale_pink            less_3_sec
# 3                cold           normal   dark_cyanotic            more_3_sec
# 4                 NaN              NaN   dark_cyanotic            more_3_sec
#
#    ... packed_cell_volume total_protein abdomo_appearance abdomo_protein  \
# 0  ...               45.0           8.4               NaN            NaN
# 1  ...               50.0          85.0            cloudy            2.0
# 2  ...               33.0           6.7               NaN            NaN
# 3  ...               48.0           7.2     serosanguious            5.3
# 4  ...               74.0           7.4               NaN            NaN
#
#       outcome  surgical_lesion lesion_1 lesion_2  lesion_3  cp_data
# 0        died               no    11300        0         0       no
# 1  euthanized               no     2208        0         0       no
# 2       lived               no        0        0         0      yes
# 3        died              yes     2208        0         0      yes
# 4        died               no     4300        0         0       no
#
# [5 rows x 28 columns]

# %% [markdown]
# # **Comprensión de los datos**

# %%
dataset.shape
# Out:
# (299, 28)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   surgery                299 non-null    object
#  1   age                    299 non-null    object
#  2   hospital_number        299 non-null    int64
#  3   rectal_temp            239 non-null    float64
#  4   pulse                  275 non-null    float64
#  5   respiratory_rate       241 non-null    float64
#  6   temp_of_extremities    243 non-null    object
#  7   peripheral_pulse       230 non-null    object
#  8   mucous_membrane        252 non-null    object
#  9   capillary_refill_time  267 non-null    object
#  10  pain                   244 non-null    object
#  11  peristalsis            255 non-null    object
#  12  abdominal_distention   243 non-null    object
#  13  nasogastric_tube       195 non-null    object
#  14  nasogastric_reflux     193 non-null    object
#  15  nasogastric_reflux_ph  53 non-null     float64
#  16  rectal_exam_feces      197 non-null    object
#  17  abdomen                181 non-null    object
#  18  packed_cell_volume     270 non-null    float64
#  19  total_protein          266 non-null    float64
#  20  abdomo_appearance      134 non-null    object
#  21  abdomo_protein         101 non-null    float64
#  22  outcome                299 non-null    object
#  23  surgical_lesion        299 non-null    object
#  24  lesion_1               299 non-null    int64
#  25  lesion_2               299 non-null    int64
#  26  lesion_3               299 non-null    int64
#  27  cp_data                299 non-null    object
# dtypes: float64(7), int64(4), object(17)
# memory usage: 65.5+ KB

# %%
dataset.isnull() # Otra forma de detectar missing values
# Out:
#      surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0      False  False            False        False  False             False
# 1      False  False            False        False  False             False
# 2      False  False            False        False  False             False
# 3      False  False            False        False  False             False
# 4      False  False            False        False  False             False
# ..       ...    ...              ...          ...    ...               ...
# 294    False  False            False         True  False             False
# 295    False  False            False        False  False             False
# 296    False  False            False        False  False             False
# 297    False  False            False        False  False             False
# 298    False  False            False        False  False             False
#
#      temp_of_extremities  peripheral_pulse  mucous_membrane  \
# 0                  False             False             True
# 1                   True              True            False
# 2                  False             False            False
# 3                  False             False            False
# 4                   True              True            False
# ..                   ...               ...              ...
# 294                False              True            False
# 295                False             False            False
# 296                False             False            False
# 297                False             False            False
# 298                 True              True             True
#
#      capillary_refill_time  ...  packed_cell_volume  total_protein  \
# 0                    False  ...               False          False
# 1                    False  ...               False          False
# 2                    False  ...               False          False
# 3                    False  ...               False          False
# 4                    False  ...               False          False
# ..                     ...  ...                 ...            ...
# 294                  False  ...               False          False
# 295                  False  ...               False           True
# 296                  False  ...               False          False
# 297                  False  ...               False          False
# 298                   True  ...               False          False
#
#      abdomo_appearance  abdomo_protein  outcome  surgical_lesion  lesion_1  \
# 0                 True            True    False            False     False
# 1                False           False    False            False     False
# 2                 True            True    False            False     False
# 3                False           False    False            False     False
# 4                 True            True    False            False     False
# ..                 ...             ...      ...              ...       ...
# 294               True            True    False            False     False
# 295              False           False    False            False     False
# 296               True            True    False            False     False
# 297              False           False    False            False     False
# 298              False           False    False            False     False
#
#      lesion_2  lesion_3  cp_data
# 0       False     False    False
# 1       False     False    False
# 2       False     False    False
# 3       False     False    False
# 4       False     False    False
# ..        ...       ...      ...
# 294     False     False    False
# 295     False     False    False
# 296     False     False    False
# 297     False     False    False
# 298     False     False    False
#
# [299 rows x 28 columns]

# %%
sns.heatmap(dataset.isnull(), cbar=False) # Otra forma de detectar missing values
# Out:
# <Axes: >

# %%
import missingno as msno

msno.bar(dataset)
# Out:
# <Axes: >

# %% [markdown]
# # **Limpieza de datos**

# %% [markdown]
# ##**SURGERY**
#
# **1 = Yes, it had surgery**
#
# **2 = It was treated without surgery**

# %%
dataset['surgery'].value_counts()
# Out:
# surgery
# yes    180
# no     119
# Name: count, dtype: int64

# %%
dataset['surgery'] = dataset['surgery'].map({'yes': 1, 'no':0})

# %%
dataset.head()
# Out:
#    surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0        0  adult           530101         38.5   66.0              28.0
# 1        1  adult           534817         39.2   88.0              20.0
# 2        0  adult           530334         38.3   40.0              24.0
# 3        1  young          5290409         39.1  164.0              84.0
# 4        0  adult           530255         37.3  104.0              35.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0                cool          reduced             NaN            more_3_sec
# 1                 NaN              NaN   pale_cyanotic            less_3_sec
# 2              normal           normal       pale_pink            less_3_sec
# 3                cold           normal   dark_cyanotic            more_3_sec
# 4                 NaN              NaN   dark_cyanotic            more_3_sec
#
#    ... packed_cell_volume total_protein abdomo_appearance abdomo_protein  \
# 0  ...               45.0           8.4               NaN            NaN
# 1  ...               50.0          85.0            cloudy            2.0
# 2  ...               33.0           6.7               NaN            NaN
# 3  ...               48.0           7.2     serosanguious            5.3
# 4  ...               74.0           7.4               NaN            NaN
#
#       outcome  surgical_lesion lesion_1 lesion_2  lesion_3  cp_data
# 0        died               no    11300        0         0       no
# 1  euthanized               no     2208        0         0       no
# 2       lived               no        0        0         0      yes
# 3        died              yes     2208        0         0      yes
# 4        died               no     4300        0         0       no
#
# [5 rows x 28 columns]

# %% [markdown]
# ##**AGE**
#
# **1 = Adult horse**
#
# **2 = Young (< 6 months)**

# %%
dataset['age'].value_counts()
# Out:
# age
# adult    275
# young     24
# Name: count, dtype: int64

# %%
dataset['age'] = dataset['age'].map({'adult': 1, 'young':0})
dataset['age'].value_counts()
# Out:
# age
# 1    275
# 0     24
# Name: count, dtype: int64

# %% [markdown]
# ##**Hospital Number: The case number assigned to the horse (may not be unique if the horse is treated > 1 time)**

# %%
dataset['hospital_number'].value_counts()
# Out:
# hospital_number
# 530693     2
# 528931     2
# 528996     2
# 532349     2
# 528890     2
#           ..
# 533696     1
# 5297379    1
# 533736     1
# 534963     1
# 534618     1
# Name: count, Length: 283, dtype: int64

# %%
# No nos aporta mucha información
# En todo caso puede ser interesante el número de hospitalizaciones (NH)

dataset['NH'] = dataset['hospital_number'].map(lambda x: (dataset['hospital_number'] == x).sum())
dataset = dataset.drop(['hospital_number'], axis=1)

# %%
dataset['NH'].value_counts()
# Out:
# NH
# 1    267
# 2     32
# Name: count, dtype: int64

# %% [markdown]
# ##**Pulse**

# %%
nan_per=dataset['pulse'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 8.03  % valores nulos

# %%
sns.boxplot(x='outcome', y='pulse', data = dataset)
# Out:
# <Axes: xlabel='outcome', ylabel='pulse'>

# %%
dataset.pulse.describe()
# Out:
# count    275.000000
# mean      72.000000
# std       28.646219
# min       30.000000
# 25%       48.000000
# 50%       64.000000
# 75%       88.000000
# max      184.000000
# Name: pulse, dtype: float64

# %%
# Simplemente consideramos la media:
dataset['pulse']=dataset['pulse'].fillna(dataset['pulse'].mean())

# %%
# Podemos considerar normal 1 (48-88), alto 2 (> 88), bajo 3 (< 48)
dataset.pulse.describe()
# Out:
# count    299.000000
# mean      72.000000
# std       27.468469
# min       30.000000
# 25%       48.500000
# 50%       68.000000
# 75%       88.000000
# max      184.000000
# Name: pulse, dtype: float64

# %% [markdown]
# ##**Respiratory Rate**

# %%
nan_per=dataset['respiratory_rate'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 19.4  % valores nulos

# %%
sns.boxplot(x='outcome', y='respiratory_rate', data = dataset)
# Out:
# <Axes: xlabel='outcome', ylabel='respiratory_rate'>

# %%
dataset.respiratory_rate.describe()
# Out:
# count    241.000000
# mean      30.460581
# std       17.666102
# min        8.000000
# 25%       18.000000
# 50%       25.000000
# 75%       36.000000
# max       96.000000
# Name: respiratory_rate, dtype: float64

# %%
# Simplemente consideramos la media:
dataset['respiratory_rate']=dataset['respiratory_rate'].fillna(dataset['respiratory_rate'].mean())

# %%
dataset.respiratory_rate.describe()
# Out:
# count    299.000000
# mean      30.460581
# std       15.853977
# min        8.000000
# 25%       20.000000
# 50%       30.000000
# 75%       34.500000
# max       96.000000
# Name: respiratory_rate, dtype: float64

# %% [markdown]
# ##**Temperature of Extremities**

# %%
nan_per=dataset['temp_of_extremities'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 18.73  % valores nulos

# %%
dataset.temp_of_extremities.value_counts()
# Out:
# temp_of_extremities
# cool      108
# normal     78
# warm       30
# cold       27
# Name: count, dtype: int64

# %%
# El valor mas repetido es cool asi que introducimos ese valor en todas las ocurencias que están a NaN
dataset['temp_of_extremities'].fillna('cool' , inplace=True)
dataset['temp_of_extremities']=dataset['temp_of_extremities'].astype('category').cat.codes
dataset['temp_of_extremities'].unique()
# Out:
# <ipython-input-79-94a8102fd52f>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['temp_of_extremities'].fillna('cool' , inplace=True)
# array([1, 2, 0, 3], dtype=int8)

# %% [markdown]
# ##**Rectal Temperature**

# %%
# Vemos que relación tienen con cp_data, la variable objetivo

sns.boxplot(x='outcome', y='rectal_temp', data = dataset)
# Out:
# <Axes: xlabel='outcome', ylabel='rectal_temp'>

# %%
# Y el total y el porcentaje de valores nulos

dataset['rectal_temp'].isna().value_counts()
# Out:
# rectal_temp
# False    239
# True      60
# Name: count, dtype: int64

# %%
nan_per=dataset['rectal_temp'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 20.07  % valores nulos

# %% [markdown]
# Para rellenar los valores nulos tenemos varias posibilidades:

# %%
# Vamos a usar RandomForestRegressor

from sklearn.ensemble import RandomForestRegressor

# Consideramos que influyen los siguientes campos:
dataset_sub = dataset[['rectal_temp', 'pulse','respiratory_rate','temp_of_extremities']]

# Dividimos la base de datos en dos grupos:
# por un lado la temperatura, que lo ponemos en y,
# y lo que nos sirve para predecir la temperatura, que lo ponemos en X (en X ponemos las variable y en y el target).
# Y en ambos casos se ejecuta dropna para eliminar los valores nulos.
X_train  = dataset_sub.dropna(subset=['rectal_temp']).drop('rectal_temp', axis=1)
y_train  = dataset['rectal_temp'].dropna()
X_test = dataset_sub.loc[np.isnan(dataset_sub.rectal_temp)].drop('rectal_temp', axis=1)

#Aplicamos el algortimo
regressor = RandomForestRegressor(n_estimators = 300)
regressor.fit(X_train, y_train)
#Predecimos los valores que nos faltan
y_pred = np.round(regressor.predict(X_test),1)
dataset.rectal_temp.loc[np.isnan(dataset.rectal_temp)] = y_pred
# Out:
# <ipython-input-83-90b67ed5e058>:21: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataset.rectal_temp.loc[np.isnan(dataset.rectal_temp)] = y_pred
# <ipython-input-83-90b67ed5e058>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.rectal_temp.loc[np.isnan(dataset.rectal_temp)] = y_pred

# %%
dataset['rectal_temp'].unique()
# Out:
# array([38.5, 39.2, 38.3, 39.1, 37.3, 37.8, 37.9, 38. , 38.1, 37.2, 38.2,
#        37.6, 38.8, 37.5, 39.4, 39.9, 38.4, 38.6, 38.7, 37.7, 37. , 39. ,
#        35.4, 38.9, 37.4, 40.3, 39.7, 36.4, 39.6, 36.8, 39.5, 36.5, 36. ,
#        37.1, 39.3, 36.1, 36.6, 40.8, 36.9, 40. ])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   surgery                299 non-null    int64
#  1   age                    299 non-null    int64
#  2   rectal_temp            299 non-null    float64
#  3   pulse                  299 non-null    float64
#  4   respiratory_rate       299 non-null    float64
#  5   temp_of_extremities    299 non-null    int8
#  6   peripheral_pulse       230 non-null    object
#  7   mucous_membrane        252 non-null    object
#  8   capillary_refill_time  267 non-null    object
#  9   pain                   244 non-null    object
#  10  peristalsis            255 non-null    object
#  11  abdominal_distention   243 non-null    object
#  12  nasogastric_tube       195 non-null    object
#  13  nasogastric_reflux     193 non-null    object
#  14  nasogastric_reflux_ph  53 non-null     float64
#  15  rectal_exam_feces      197 non-null    object
#  16  abdomen                181 non-null    object
#  17  packed_cell_volume     270 non-null    float64
#  18  total_protein          266 non-null    float64
#  19  abdomo_appearance      134 non-null    object
#  20  abdomo_protein         101 non-null    float64
#  21  outcome                299 non-null    object
#  22  surgical_lesion        299 non-null    object
#  23  lesion_1               299 non-null    int64
#  24  lesion_2               299 non-null    int64
#  25  lesion_3               299 non-null    int64
#  26  cp_data                299 non-null    object
#  27  NH                     299 non-null    int64
# dtypes: float64(7), int64(6), int8(1), object(14)
# memory usage: 63.5+ KB

# %% [markdown]
# ##**Peripheral pulse**

# %%
nan_per=dataset['peripheral_pulse'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 23.08  % valores nulos

# %%
dataset.peripheral_pulse.value_counts()
# Out:
# peripheral_pulse
# normal       114
# reduced      103
# absent         8
# increased      5
# Name: count, dtype: int64

# %%
# El valor mas repetido es normal asi que introducimos ese valor en todas las ocurencias que están a NaN
dataset['peripheral_pulse'].fillna('normal' , inplace=True)
dataset['peripheral_pulse']=dataset['peripheral_pulse'].astype('category').cat.codes
dataset['peripheral_pulse'].unique()
# Out:
# <ipython-input-88-fca69f660ea6>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['peripheral_pulse'].fillna('normal' , inplace=True)
# array([3, 2, 0, 1], dtype=int8)

# %% [markdown]
# ##**Mucuos membranes**

# %%
nan_per=dataset['mucous_membrane'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 15.72  % valores nulos

# %%
dataset.mucous_membrane.value_counts()
# Out:
# mucous_membrane
# normal_pink      79
# pale_pink        57
# pale_cyanotic    41
# bright_pink      30
# bright_red       25
# dark_cyanotic    20
# Name: count, dtype: int64

# %%
dataset['mucous_membrane'].fillna('normal_pink' , inplace=True)
dataset['mucous_membrane']=dataset['mucous_membrane'].astype('category').cat.codes
dataset['mucous_membrane'].unique()
# Out:
# <ipython-input-91-594e9213e7dd>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['mucous_membrane'].fillna('normal_pink' , inplace=True)
# array([3, 4, 5, 2, 1, 0], dtype=int8)

# %% [markdown]
# ##**Capillary refill time (a clinical judgement, the longer the refill, the poorer the circulation)**

# %%
nan_per=dataset['capillary_refill_time'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 10.7  % valores nulos

# %%
dataset.capillary_refill_time.value_counts()
# Out:
# capillary_refill_time
# less_3_sec    187
# more_3_sec     78
# 3               2
# Name: count, dtype: int64

# %%
dataset['capillary_refill_time'].fillna('less_3_sec' , inplace=True)
dataset['capillary_refill_time']=dataset['capillary_refill_time'].astype('category').cat.codes
dataset['capillary_refill_time'].unique()
# Out:
# <ipython-input-94-fe26cdfe1df4>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['capillary_refill_time'].fillna('less_3_sec' , inplace=True)
# array([2, 1, 0], dtype=int8)

# %% [markdown]
# ##**Pain**

# %%
nan_per=dataset['pain'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 18.39  % valores nulos

# %%
dataset.pain.value_counts()
# Out:
# pain
# mild_pain       67
# depressed       59
# extreme_pain    42
# severe_pain     38
# alert           38
# Name: count, dtype: int64

# %%
dataset['pain'].fillna('mild_pain' , inplace=True)
dataset['pain']=dataset['pain'].astype('category').cat.codes
dataset['pain'].unique()
# Out:
# <ipython-input-97-8170e6e222cc>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['pain'].fillna('mild_pain' , inplace=True)
# array([2, 3, 1, 4, 0], dtype=int8)

# %% [markdown]
# ##**Peristalsis (an indication of the activity in the horse's gut)**

# %%
nan_per=dataset['peristalsis'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 14.72  % valores nulos

# %%
dataset.peristalsis.value_counts()
# Out:
# peristalsis
# hypomotile     127
# absent          73
# hypermotile     39
# normal          16
# Name: count, dtype: int64

# %%
dataset['peristalsis'].fillna('hypomotile' , inplace=True)
dataset['peristalsis']=dataset['peristalsis'].astype('category').cat.codes
dataset['peristalsis'].unique()
# Out:
# <ipython-input-100-8d444cbf6565>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['peristalsis'].fillna('hypomotile' , inplace=True)
# array([0, 2, 1, 3], dtype=int8)

# %% [markdown]
# ##**Abdominal distension**

# %%
nan_per=dataset['abdominal_distention'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 18.73  % valores nulos

# %%
dataset.abdominal_distention.value_counts()
# Out:
# abdominal_distention
# none        75
# slight      65
# moderate    65
# severe      38
# Name: count, dtype: int64

# %%
dataset['abdominal_distention'].fillna('none' , inplace=True)
dataset['abdominal_distention']=dataset['abdominal_distention'].astype('category').cat.codes
dataset['abdominal_distention'].unique()
# Out:
# <ipython-input-103-8b33f6ed3ddb>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['abdominal_distention'].fillna('none' , inplace=True)
# array([2, 3, 1, 0], dtype=int8)

# %% [markdown]
# ##**Nasogastric tube (refers to any gas coming out of the tube)**

# %%
nan_per=dataset['nasogastric_tube'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 34.78  % valores nulos

# %%
dataset.nasogastric_tube.value_counts()
# Out:
# nasogastric_tube
# slight         101
# none            71
# significant     23
# Name: count, dtype: int64

# %%
dataset['nasogastric_tube'].fillna('slight' , inplace=True)
dataset['nasogastric_tube']=dataset['nasogastric_tube'].astype('category').cat.codes
dataset['nasogastric_tube'].unique()
# Out:
# <ipython-input-106-cdadf9e435f3>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['nasogastric_tube'].fillna('slight' , inplace=True)
# array([2, 0, 1], dtype=int8)

# %% [markdown]
# ##**Nasogastric reflux**

# %%
nan_per=dataset['nasogastric_reflux'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 35.45  % valores nulos

# %%
dataset.nasogastric_reflux.value_counts()
# Out:
# nasogastric_reflux
# none            119
# more_1_liter     39
# less_1_liter     35
# Name: count, dtype: int64

# %%
dataset['nasogastric_reflux'].fillna('none' , inplace=True)
dataset['nasogastric_reflux']=dataset['nasogastric_reflux'].astype('category').cat.codes
dataset['nasogastric_reflux'].unique()
# Out:
# <ipython-input-109-d9697eb2addd>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['nasogastric_reflux'].fillna('none' , inplace=True)
# array([2, 0, 1], dtype=int8)

# %% [markdown]
# ##**Nasogastric reflux PH**

# %%
nan_per=dataset['nasogastric_reflux_ph'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 82.27  % valores nulos

# %%
# Eliminamos la columna
dataset = dataset.drop(['nasogastric_reflux_ph'], axis=1)

# %% [markdown]
# ##**Rectal examination - feces**

# %%
nan_per=dataset['rectal_exam_feces'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 34.11  % valores nulos

# %%
dataset.rectal_exam_feces.value_counts()
# Out:
# rectal_exam_feces
# absent       79
# normal       57
# decreased    48
# increased    13
# Name: count, dtype: int64

# %%
dataset['rectal_exam_feces'].fillna('absent' , inplace=True)
dataset['rectal_exam_feces']=dataset['rectal_exam_feces'].astype('category').cat.codes
dataset['rectal_exam_feces'].unique()
# Out:
# <ipython-input-114-2ec10b8d5982>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['rectal_exam_feces'].fillna('absent' , inplace=True)
# array([1, 0, 3, 2], dtype=int8)

# %% [markdown]
# ##**Abdomen**

# %%
nan_per=dataset['abdomen'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 39.46  % valores nulos

# %%
dataset.abdomen.value_counts()
# Out:
# abdomen
# distend_large    78
# distend_small    43
# normal           28
# other            19
# firm             13
# Name: count, dtype: int64

# %%
dataset['abdomen'].fillna('distend_large' , inplace=True)
dataset['abdomen']=dataset['abdomen'].astype('category').cat.codes
dataset['abdomen'].unique()
# Out:
# <ipython-input-117-a0a1c3afa495>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['abdomen'].fillna('distend_large' , inplace=True)
# array([0, 4, 3, 2, 1], dtype=int8)

# %% [markdown]
# ##**Packed_cell_volume (red cells by volume in the blood)**

# %%
nan_per=dataset['packed_cell_volume'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 9.7  % valores nulos

# %%
# Simplemente consideramos la media:
dataset['packed_cell_volume']=dataset['packed_cell_volume'].fillna(dataset['packed_cell_volume'].mean())

# %%
dataset.packed_cell_volume.describe()
# Out:
# count    299.000000
# mean      46.307407
# std        9.915919
# min       23.000000
# 25%       39.000000
# 50%       46.000000
# 75%       50.000000
# max       75.000000
# Name: packed_cell_volume, dtype: float64

# %% [markdown]
# ##**Total protein**

# %%
nan_per=dataset['total_protein'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 11.04  % valores nulos

# %%
# Simplemente consideramos la media:
dataset['total_protein']=dataset['total_protein'].fillna(dataset['total_protein'].mean())

# %%
dataset.packed_cell_volume.describe()
# Out:
# count    299.000000
# mean      46.307407
# std        9.915919
# min       23.000000
# 25%       39.000000
# 50%       46.000000
# 75%       50.000000
# max       75.000000
# Name: packed_cell_volume, dtype: float64

# %% [markdown]
# ##**Abdominocentesis appearance (a needle is put in the horse's abdomen and fluid is obtained from the abdominal cavity)**

# %%
nan_per=dataset['abdomo_appearance'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 55.18  % valores nulos

# %%
# Eliminamos la columna
dataset = dataset.drop(['abdomo_appearance'], axis=1)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   surgery                299 non-null    int64
#  1   age                    299 non-null    int64
#  2   rectal_temp            299 non-null    float64
#  3   pulse                  299 non-null    float64
#  4   respiratory_rate       299 non-null    float64
#  5   temp_of_extremities    299 non-null    int8
#  6   peripheral_pulse       299 non-null    int8
#  7   mucous_membrane        299 non-null    int8
#  8   capillary_refill_time  299 non-null    int8
#  9   pain                   299 non-null    int8
#  10  peristalsis            299 non-null    int8
#  11  abdominal_distention   299 non-null    int8
#  12  nasogastric_tube       299 non-null    int8
#  13  nasogastric_reflux     299 non-null    int8
#  14  rectal_exam_feces      299 non-null    int8
#  15  abdomen                299 non-null    int8
#  16  packed_cell_volume     299 non-null    float64
#  17  total_protein          299 non-null    float64
#  18  abdomo_protein         101 non-null    float64
#  19  outcome                299 non-null    object
#  20  surgical_lesion        299 non-null    object
#  21  lesion_1               299 non-null    int64
#  22  lesion_2               299 non-null    int64
#  23  lesion_3               299 non-null    int64
#  24  cp_data                299 non-null    object
#  25  NH                     299 non-null    int64
# dtypes: float64(6), int64(6), int8(11), object(3)
# memory usage: 38.4+ KB

# %% [markdown]
# ##**Abdomcentesis total protein**

# %%
nan_per=dataset['abdomo_protein'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 66.22  % valores nulos

# %%
# Eliminamos la columna
dataset = dataset.drop(['abdomo_protein'], axis=1)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   surgery                299 non-null    int64
#  1   age                    299 non-null    int64
#  2   rectal_temp            299 non-null    float64
#  3   pulse                  299 non-null    float64
#  4   respiratory_rate       299 non-null    float64
#  5   temp_of_extremities    299 non-null    int8
#  6   peripheral_pulse       299 non-null    int8
#  7   mucous_membrane        299 non-null    int8
#  8   capillary_refill_time  299 non-null    int8
#  9   pain                   299 non-null    int8
#  10  peristalsis            299 non-null    int8
#  11  abdominal_distention   299 non-null    int8
#  12  nasogastric_tube       299 non-null    int8
#  13  nasogastric_reflux     299 non-null    int8
#  14  rectal_exam_feces      299 non-null    int8
#  15  abdomen                299 non-null    int8
#  16  packed_cell_volume     299 non-null    float64
#  17  total_protein          299 non-null    float64
#  18  outcome                299 non-null    object
#  19  surgical_lesion        299 non-null    object
#  20  lesion_1               299 non-null    int64
#  21  lesion_2               299 non-null    int64
#  22  lesion_3               299 non-null    int64
#  23  cp_data                299 non-null    object
#  24  NH                     299 non-null    int64
# dtypes: float64(5), int64(6), int8(11), object(3)
# memory usage: 36.0+ KB

# %% [markdown]
# ##**Outcome (what eventually happened to the horse?)**

# %%
nan_per=dataset['outcome'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 0.0  % valores nulos

# %%
dataset.outcome.value_counts()
# Out:
# outcome
# lived         178
# died           77
# euthanized     44
# Name: count, dtype: int64

# %%
dataset['outcome']=dataset['outcome'].astype('category').cat.codes
dataset['outcome'].unique()
# Out:
# array([0, 1, 2], dtype=int8)

# %% [markdown]
# ##**Surgical lesion?**

# %%
nan_per=dataset['surgical_lesion'].isna().sum()/len(dataset)*100
print (round(nan_per,2), ' % valores nulos')
# Out:
# 0.0  % valores nulos

# %%
dataset['surgical_lesion'].value_counts()
# Out:
# surgical_lesion
# yes    190
# no     109
# Name: count, dtype: int64

# %%
dataset['surgical_lesion'] = dataset['surgical_lesion'].map({'yes': 1, 'no':0})
dataset['surgical_lesion'].value_counts()
# Out:
# surgical_lesion
# 1    190
# 0    109
# Name: count, dtype: int64

# %% [markdown]
# ##**Lesion**

# %%
dataset['lesion_1'].value_counts()
# Out:
# lesion_1
# 0        56
# 3111     32
# 3205     29
# 2208     20
# 2205     13
#          ..
# 5205      1
# 2305      1
# 5000      1
# 7400      1
# 11300     1
# Name: count, Length: 61, dtype: int64

# %%
dataset['lesion_2'].value_counts()
# Out:
# lesion_2
# 0       292
# 3111      3
# 1400      1
# 7111      1
# 6112      1
# 3112      1
# Name: count, dtype: int64

# %%
dataset['lesion_3'].value_counts()
# Out:
# lesion_3
# 0       298
# 2209      1
# Name: count, dtype: int64

# %%
# lesion1, 2 and 3 son datos con formato, cada dígito tiene un significado por lo que no nos sirve
# Se puede crear una nueva caracterísca simplemente con el total de lesiones
dataset.loc[dataset['lesion_1'] > 0, 'lesion_1'] = 1
dataset.loc[dataset['lesion_2'] > 0, 'lesion_2'] = 1
dataset.loc[dataset['lesion_3'] > 0, 'lesion_3'] = 1

dataset['TL'] = dataset['lesion_1'] + dataset['lesion_2'] + dataset['lesion_3']
dataset = dataset.drop(columns = ['lesion_1','lesion_2', 'lesion_3'], axis = 1)
dataset['TL'].value_counts()
# Out:
# TL
# 1    236
# 0     56
# 2      6
# 3      1
# Name: count, dtype: int64

# %% [markdown]
# ##**CP Data (No es significativa)**

# %%
# Eliminamos la columna
dataset = dataset.drop(['cp_data'], axis=1)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   surgery                299 non-null    int64
#  1   age                    299 non-null    int64
#  2   rectal_temp            299 non-null    float64
#  3   pulse                  299 non-null    float64
#  4   respiratory_rate       299 non-null    float64
#  5   temp_of_extremities    299 non-null    int8
#  6   peripheral_pulse       299 non-null    int8
#  7   mucous_membrane        299 non-null    int8
#  8   capillary_refill_time  299 non-null    int8
#  9   pain                   299 non-null    int8
#  10  peristalsis            299 non-null    int8
#  11  abdominal_distention   299 non-null    int8
#  12  nasogastric_tube       299 non-null    int8
#  13  nasogastric_reflux     299 non-null    int8
#  14  rectal_exam_feces      299 non-null    int8
#  15  abdomen                299 non-null    int8
#  16  packed_cell_volume     299 non-null    float64
#  17  total_protein          299 non-null    float64
#  18  outcome                299 non-null    int8
#  19  surgical_lesion        299 non-null    int64
#  20  NH                     299 non-null    int64
#  21  TL                     299 non-null    int64
# dtypes: float64(5), int64(5), int8(12)
# memory usage: 27.0 KB

# %% [markdown]
# ##**Otra posibilidad**

# %%
# Como lo que hemos hecho para las columnas de tipo object que tienen valores nan que no superen el 40 %
# es completar el dato con el valor más frecuente también se podría hacer de la siguiente forma:

#obj=[]
#for col in dataset.columns.values:
#    if dataset[col].dtype=='object':
#        obj.append(col)
#ds_obj=dataset[obj]

#for col in ds_obj.columns.values:
#    if (pd.isna(ds_obj[col]).sum()) > 0:
#        if pd.isna(ds_obj[col]).sum() > (40/100*len(ds_obj)):
#            ds_obj=ds_obj.drop([col], axis=1)
#        else:
#            ds_obj[col]=ds_obj[col].fillna(ds_obj[col].mode()[0])
#            ds_obj[col]=ds_obj[col].astype('category').cat.codes

#ds_obj.info()

# %% [markdown]
# #**Normalización 1**

# %%
dataset.describe()
# Out:
#           surgery         age  rectal_temp       pulse  respiratory_rate  \
# count  299.000000  299.000000   299.000000  299.000000        299.000000
# mean     0.602007    0.919732    38.193645   72.000000         30.460581
# std      0.490305    0.272162     0.686490   27.468469         15.853977
# min      0.000000    0.000000    35.400000   30.000000          8.000000
# 25%      0.000000    1.000000    37.800000   48.500000         20.000000
# 50%      1.000000    1.000000    38.200000   68.000000         30.000000
# 75%      1.000000    1.000000    38.600000   88.000000         34.500000
# max      1.000000    1.000000    40.800000  184.000000         96.000000
#
#        temp_of_extremities  peripheral_pulse  mucous_membrane  \
# count           299.000000        299.000000       299.000000
# mean              1.371237          2.274247         2.983278
# std               0.785337          0.627961         1.486986
# min               0.000000          0.000000         0.000000
# 25%               1.000000          2.000000         2.500000
# 50%               1.000000          2.000000         3.000000
# 75%               2.000000          3.000000         4.000000
# max               3.000000          3.000000         5.000000
#
#        capillary_refill_time        pain  ...  nasogastric_tube  \
# count             299.000000  299.000000  ...        299.000000
# mean                1.254181    2.210702  ...          1.448161
# std                 0.451256    1.258162  ...          0.851265
# min                 0.000000    0.000000  ...          0.000000
# 25%                 1.000000    1.000000  ...          1.000000
# 50%                 1.000000    3.000000  ...          2.000000
# 75%                 2.000000    3.000000  ...          2.000000
# max                 2.000000    4.000000  ...          2.000000
#
#        nasogastric_reflux  rectal_exam_feces     abdomen  packed_cell_volume  \
# count          299.000000         299.000000  299.000000          299.000000
# mean             1.635452           0.819398    0.765886           46.307407
# std              0.683615           1.176172    1.263334            9.915919
# min              0.000000           0.000000    0.000000           23.000000
# 25%              2.000000           0.000000    0.000000           39.000000
# 50%              2.000000           0.000000    0.000000           46.000000
# 75%              2.000000           1.000000    1.000000           50.000000
# max              2.000000           3.000000    4.000000           75.000000
#
#        total_protein     outcome  surgical_lesion          NH          TL
# count     299.000000  299.000000       299.000000  299.000000  299.000000
# mean       24.274436    1.337793         0.635452    1.107023    0.839465
# std        25.804620    0.860940         0.482110    0.309661    0.442288
# min         3.300000    0.000000         0.000000    1.000000    0.000000
# 25%         6.600000    0.000000         0.000000    1.000000    1.000000
# 50%         7.700000    2.000000         1.000000    1.000000    1.000000
# 75%        52.000000    2.000000         1.000000    1.000000    1.000000
# max        89.000000    2.000000         1.000000    2.000000    3.000000
#
# [8 rows x 22 columns]

# %%
def normalize (horses):
  result = horses.copy()

  for feature_name in horses.columns:
    max_value = horses[feature_name].max()
    min_value = horses[feature_name].min()
    result[feature_name] = (horses[feature_name] - min_value) / (max_value - min_value)
  return result

dataset_nor = normalize(dataset)
dataset_nor.describe()
# Out:
#           surgery         age  rectal_temp       pulse  respiratory_rate  \
# count  299.000000  299.000000   299.000000  299.000000        299.000000
# mean     0.602007    0.919732     0.517342    0.272727          0.255234
# std      0.490305    0.272162     0.127128    0.178367          0.180159
# min      0.000000    0.000000     0.000000    0.000000          0.000000
# 25%      0.000000    1.000000     0.444444    0.120130          0.136364
# 50%      1.000000    1.000000     0.518519    0.246753          0.250000
# 75%      1.000000    1.000000     0.592593    0.376623          0.301136
# max      1.000000    1.000000     1.000000    1.000000          1.000000
#
#        temp_of_extremities  peripheral_pulse  mucous_membrane  \
# count           299.000000        299.000000       299.000000
# mean              0.457079          0.758082         0.596656
# std               0.261779          0.209320         0.297397
# min               0.000000          0.000000         0.000000
# 25%               0.333333          0.666667         0.500000
# 50%               0.333333          0.666667         0.600000
# 75%               0.666667          1.000000         0.800000
# max               1.000000          1.000000         1.000000
#
#        capillary_refill_time        pain  ...  nasogastric_tube  \
# count             299.000000  299.000000  ...        299.000000
# mean                0.627090    0.552676  ...          0.724080
# std                 0.225628    0.314541  ...          0.425633
# min                 0.000000    0.000000  ...          0.000000
# 25%                 0.500000    0.250000  ...          0.500000
# 50%                 0.500000    0.750000  ...          1.000000
# 75%                 1.000000    0.750000  ...          1.000000
# max                 1.000000    1.000000  ...          1.000000
#
#        nasogastric_reflux  rectal_exam_feces     abdomen  packed_cell_volume  \
# count          299.000000         299.000000  299.000000          299.000000
# mean             0.817726           0.273133    0.191472            0.448219
# std              0.341808           0.392057    0.315834            0.190691
# min              0.000000           0.000000    0.000000            0.000000
# 25%              1.000000           0.000000    0.000000            0.307692
# 50%              1.000000           0.000000    0.000000            0.442308
# 75%              1.000000           0.333333    0.250000            0.519231
# max              1.000000           1.000000    1.000000            1.000000
#
#        total_protein     outcome  surgical_lesion          NH          TL
# count     299.000000  299.000000       299.000000  299.000000  299.000000
# mean        0.244743    0.668896         0.635452    0.107023    0.279822
# std         0.301104    0.430470         0.482110    0.309661    0.147429
# min         0.000000    0.000000         0.000000    0.000000    0.000000
# 25%         0.038506    0.000000         0.000000    0.000000    0.333333
# 50%         0.051342    1.000000         1.000000    0.000000    0.333333
# 75%         0.568261    1.000000         1.000000    0.000000    0.333333
# max         1.000000    1.000000         1.000000    1.000000    1.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# #**Normalización 2**

# %%
from sklearn.preprocessing import StandardScaler

target = dataset['outcome']
dataset_nor = dataset.drop(columns = ['outcome'], axis = 1)
features = dataset_nor.columns
scaler = StandardScaler()
scaledTrain = scaler.fit_transform(dataset_nor)
dfTrain = pd.DataFrame(data=scaledTrain, columns=features)
dfTrain.head()
# Out:
#     surgery       age  rectal_temp     pulse  respiratory_rate  \
# 0 -1.229880  0.295420     0.447010 -0.218798         -0.155463
# 1  0.813087  0.295420     1.468400  0.583463         -0.660914
# 2 -1.229880  0.295420     0.155185 -1.166925         -0.408189
# 3  0.813087 -3.385016     1.322487  3.354910          3.382695
# 4 -1.229880  0.295420    -1.303943  1.166925          0.286807
#
#    temp_of_extremities  peripheral_pulse  mucous_membrane  \
# 0            -0.473504          1.157667         0.011265
# 1            -0.473504         -0.437459         0.684893
# 2             0.801970         -0.437459         1.358522
# 3            -1.748977         -0.437459        -0.662364
# 4            -0.473504         -0.437459        -0.662364
#
#    capillary_refill_time      pain  ...  abdominal_distention  \
# 0               1.655535 -0.167749  ...              0.626329
# 1              -0.564218  0.628393  ...              1.581801
# 2              -0.564218  0.628393  ...             -0.329142
# 3               1.655535 -0.963892  ...              0.626329
# 4               1.655535  0.628393  ...             -0.329142
#
#    nasogastric_tube  nasogastric_reflux  rectal_exam_feces   abdomen  \
# 0          0.649345            0.534160           0.153808 -0.607258
# 1          0.649345            0.534160          -0.697833  2.564274
# 2          0.649345            0.534160           1.857090  1.771391
# 3         -1.704038           -2.396368           0.153808 -0.607258
# 4          0.649345            0.534160          -0.697833 -0.607258
#
#    packed_cell_volume  total_protein  surgical_lesion        NH        TL
# 0           -0.132070      -0.616209        -1.320272 -0.346194  0.363574
# 1            0.373015       2.357228        -1.320272 -0.346194  0.363574
# 2           -1.344274      -0.682199        -1.320272 -0.346194 -1.901188
# 3            0.170981      -0.662791         0.757419 -0.346194  0.363574
# 4            2.797423      -0.655027        -1.320272 -0.346194  0.363574
#
# [5 rows x 21 columns]

# %% [markdown]
# #**Reducción de dimensionalidad**

# %% [markdown]
# ##**Feature importance**

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import ExtraTreesClassifier

# Feature_importances of tree based classifiers
X = dataset.drop("outcome",axis=1)    # Independent columns
y = dataset["outcome"]              # Target feature
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) # Use inbuilt class
# Out:
# [0.04390041 0.01494192 0.06184438 0.07538884 0.05154739 0.05412966
#  0.04389515 0.04517984 0.03739684 0.06160332 0.03648062 0.04532765
#  0.02919586 0.03446686 0.03408478 0.02947323 0.08171904 0.11140927
#  0.05980633 0.01537785 0.03283077]

# %%
# plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %% [markdown]
# ##**Varianza**
# Se calcula la varianza de cada una de las variables y se descantan aquellas que tengan una varianza baja en comparación con las otras variables de nuestro conjunto de datos, ya que las variables con una varianza baja no afectarán a la variable objetivo.

# %%
dataset.var()
# Out:
# surgery                    0.240399
# age                        0.074072
# rectal_temp                0.471268
# pulse                    754.516779
# respiratory_rate         251.348576
# temp_of_extremities        0.616754
# peripheral_pulse           0.394335
# mucous_membrane            2.211129
# capillary_refill_time      0.203632
# pain                       1.582972
# peristalsis                0.843887
# abdominal_distention       1.099055
# nasogastric_tube           0.724653
# nasogastric_reflux         0.467330
# rectal_exam_feces          1.383381
# abdomen                    1.596014
# packed_cell_volume        98.325454
# total_protein            665.878410
# outcome                    0.741218
# surgical_lesion            0.232430
# NH                         0.095890
# TL                         0.195619
# dtype: float64

# %%
# Vamos a quitar aquellas variables cuya varianza sea menor a 0.1

dataset_var = dataset
var = dataset.var()

for col in range(len(var)):
  if var[col] < 0.1:
    dataset_var = dataset_var.drop([var.index[col]], axis=1)
dataset_var.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   surgery                299 non-null    int64
#  1   rectal_temp            299 non-null    float64
#  2   pulse                  299 non-null    float64
#  3   respiratory_rate       299 non-null    float64
#  4   temp_of_extremities    299 non-null    int8
#  5   peripheral_pulse       299 non-null    int8
#  6   mucous_membrane        299 non-null    int8
#  7   capillary_refill_time  299 non-null    int8
#  8   pain                   299 non-null    int8
#  9   peristalsis            299 non-null    int8
#  10  abdominal_distention   299 non-null    int8
#  11  nasogastric_tube       299 non-null    int8
#  12  nasogastric_reflux     299 non-null    int8
#  13  rectal_exam_feces      299 non-null    int8
#  14  abdomen                299 non-null    int8
#  15  packed_cell_volume     299 non-null    float64
#  16  total_protein          299 non-null    float64
#  17  outcome                299 non-null    int8
#  18  surgical_lesion        299 non-null    int64
#  19  TL                     299 non-null    int64
# dtypes: float64(5), int64(3), int8(12)
# memory usage: 22.3 KB
# <ipython-input-146-c42c21a3f4b2>:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if var[col] < 0.1:
# <ipython-input-146-c42c21a3f4b2>:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if var[col] < 0.1:
# <ipython-input-146-c42c21a3f4b2>:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if var[col] < 0.1:

# %% [markdown]
# #**Correlation (Pearson)**

# %%
import matplotlib.pyplot as plt

dataset.corr()
# Out:
#                         surgery       age  rectal_temp     pulse  \
# surgery                1.000000 -0.089319    -0.017509  0.179646
# age                   -0.089319  1.000000    -0.196714 -0.507224
# rectal_temp           -0.017509 -0.196714     1.000000  0.230134
# pulse                  0.179646 -0.507224     0.230134  1.000000
# respiratory_rate       0.181173 -0.375469     0.242064  0.439825
# temp_of_extremities   -0.190183  0.014282    -0.065322 -0.287472
# peripheral_pulse       0.115915 -0.027843    -0.016183  0.247265
# mucous_membrane        0.041470  0.170800    -0.149020 -0.047240
# capillary_refill_time  0.079588  0.030065     0.096224  0.375765
# pain                   0.228871 -0.058242    -0.083919  0.125354
# peristalsis           -0.061546 -0.021008    -0.058926 -0.277144
# abdominal_distention  -0.150197  0.038430    -0.027256 -0.073880
# nasogastric_tube       0.066982 -0.018020    -0.026693 -0.030281
# nasogastric_reflux    -0.083910 -0.085657    -0.011388 -0.108653
# rectal_exam_feces     -0.171611 -0.003506    -0.050883 -0.208565
# abdomen               -0.297202  0.111078    -0.054730 -0.208004
# packed_cell_volume     0.040038  0.144326     0.050123  0.369850
# total_protein          0.042420  0.112925    -0.054331 -0.079947
# outcome               -0.189222  0.101782    -0.006008 -0.344670
# surgical_lesion        0.605023 -0.044734    -0.008037  0.259733
# NH                    -0.005840  0.102272     0.113710 -0.012624
# TL                     0.447152 -0.051652    -0.034317  0.277042
#
#                        respiratory_rate  temp_of_extremities  \
# surgery                        0.181173            -0.190183
# age                           -0.375469             0.014282
# rectal_temp                    0.242064            -0.065322
# pulse                          0.439825            -0.287472
# respiratory_rate               1.000000            -0.027365
# temp_of_extremities           -0.027365             1.000000
# peripheral_pulse               0.132643            -0.193530
# mucous_membrane               -0.080842            -0.089494
# capillary_refill_time          0.083410            -0.257690
# pain                           0.097621            -0.188108
# peristalsis                   -0.057862             0.194146
# abdominal_distention          -0.034526             0.043866
# nasogastric_tube              -0.031858            -0.058958
# nasogastric_reflux            -0.165818             0.077912
# rectal_exam_feces             -0.026901             0.269007
# abdomen                       -0.164523             0.169069
# packed_cell_volume             0.073790            -0.287791
# total_protein                 -0.077715             0.030805
# outcome                       -0.079408             0.290367
# surgical_lesion                0.218532            -0.226318
# NH                            -0.045519            -0.081131
# TL                             0.181100            -0.223948
#
#                        peripheral_pulse  mucous_membrane  \
# surgery                        0.115915         0.041470
# age                           -0.027843         0.170800
# rectal_temp                   -0.016183        -0.149020
# pulse                          0.247265        -0.047240
# respiratory_rate               0.132643        -0.080842
# temp_of_extremities           -0.193530        -0.089494
# peripheral_pulse               1.000000         0.080396
# mucous_membrane                0.080396         1.000000
# capillary_refill_time          0.226861        -0.058657
# pain                           0.062531         0.154351
# peristalsis                   -0.224845        -0.173991
# abdominal_distention          -0.133792        -0.007055
# nasogastric_tube              -0.067478         0.064263
# nasogastric_reflux            -0.227529        -0.039029
# rectal_exam_feces             -0.132625        -0.028594
# abdomen                       -0.121833         0.017558
# packed_cell_volume             0.239227        -0.132105
# total_protein                 -0.038235        -0.011503
# outcome                       -0.165719         0.056852
# surgical_lesion                0.165077         0.075724
# NH                             0.038381         0.084064
# TL                             0.195295         0.108157
#
#                        capillary_refill_time      pain  ...  nasogastric_tube  \
# surgery                             0.079588  0.228871  ...          0.066982
# age                                 0.030065 -0.058242  ...         -0.018020
# rectal_temp                         0.096224 -0.083919  ...         -0.026693
# pulse                               0.375765  0.125354  ...         -0.030281
# respiratory_rate                    0.083410  0.097621  ...         -0.031858
# temp_of_extremities                -0.257690 -0.188108  ...         -0.058958
# peripheral_pulse                    0.226861  0.062531  ...         -0.067478
# mucous_membrane                    -0.058657  0.154351  ...          0.064263
# capillary_refill_time               1.000000  0.059026  ...         -0.026733
# pain                                0.059026  1.000000  ...          0.099528
# peristalsis                        -0.235108 -0.024363  ...         -0.018284
# abdominal_distention                0.034186 -0.065390  ...         -0.053246
# nasogastric_tube                   -0.026733  0.099528  ...          1.000000
# nasogastric_reflux                 -0.166372 -0.050850  ...          0.102928
# rectal_exam_feces                  -0.172442 -0.130667  ...         -0.052953
# abdomen                            -0.142492 -0.296097  ...          0.060445
# packed_cell_volume                  0.472536  0.025235  ...         -0.021623
# total_protein                      -0.069844 -0.075915  ...         -0.026171
# outcome                            -0.256294 -0.161964  ...          0.049156
# surgical_lesion                     0.165131  0.276427  ...          0.023299
# NH                                  0.188904 -0.049461  ...         -0.055263
# TL                                  0.205135  0.272051  ...         -0.013265
#
#                        nasogastric_reflux  rectal_exam_feces   abdomen  \
# surgery                         -0.083910          -0.171611 -0.297202
# age                             -0.085657          -0.003506  0.111078
# rectal_temp                     -0.011388          -0.050883 -0.054730
# pulse                           -0.108653          -0.208565 -0.208004
# respiratory_rate                -0.165818          -0.026901 -0.164523
# temp_of_extremities              0.077912           0.269007  0.169069
# peripheral_pulse                -0.227529          -0.132625 -0.121833
# mucous_membrane                 -0.039029          -0.028594  0.017558
# capillary_refill_time           -0.166372          -0.172442 -0.142492
# pain                            -0.050850          -0.130667 -0.296097
# peristalsis                      0.146367           0.113293  0.108243
# abdominal_distention             0.058756           0.009803  0.114305
# nasogastric_tube                 0.102928          -0.052953  0.060445
# nasogastric_reflux               1.000000           0.072262  0.071811
# rectal_exam_feces                0.072262           1.000000  0.237937
# abdomen                          0.071811           0.237937  1.000000
# packed_cell_volume              -0.281882          -0.237598 -0.052250
# total_protein                    0.108381          -0.054706 -0.029447
# outcome                          0.181422           0.193004  0.214875
# surgical_lesion                 -0.211128          -0.199348 -0.316903
# NH                              -0.037006           0.136169  0.115729
# TL                              -0.183108          -0.281696 -0.217630
#
#                        packed_cell_volume  total_protein   outcome  \
# surgery                          0.040038       0.042420 -0.189222
# age                              0.144326       0.112925  0.101782
# rectal_temp                      0.050123      -0.054331 -0.006008
# pulse                            0.369850      -0.079947 -0.344670
# respiratory_rate                 0.073790      -0.077715 -0.079408
# temp_of_extremities             -0.287791       0.030805  0.290367
# peripheral_pulse                 0.239227      -0.038235 -0.165719
# mucous_membrane                 -0.132105      -0.011503  0.056852
# capillary_refill_time            0.472536      -0.069844 -0.256294
# pain                             0.025235      -0.075915 -0.161964
# peristalsis                     -0.265939      -0.116132  0.165844
# abdominal_distention            -0.057302      -0.012287  0.112309
# nasogastric_tube                -0.021623      -0.026171  0.049156
# nasogastric_reflux              -0.281882       0.108381  0.181422
# rectal_exam_feces               -0.237598      -0.054706  0.193004
# abdomen                         -0.052250      -0.029447  0.214875
# packed_cell_volume               1.000000      -0.051740 -0.401140
# total_protein                   -0.051740       1.000000  0.245657
# outcome                         -0.401140       0.245657  1.000000
# surgical_lesion                  0.163993      -0.113224 -0.332933
# NH                               0.134179      -0.124887 -0.098297
# TL                               0.204697      -0.108678 -0.271305
#
#                        surgical_lesion        NH        TL
# surgery                       0.605023 -0.005840  0.447152
# age                          -0.044734  0.102272 -0.051652
# rectal_temp                  -0.008037  0.113710 -0.034317
# pulse                         0.259733 -0.012624  0.277042
# respiratory_rate              0.218532 -0.045519  0.181100
# temp_of_extremities          -0.226318 -0.081131 -0.223948
# peripheral_pulse              0.165077  0.038381  0.195295
# mucous_membrane               0.075724  0.084064  0.108157
# capillary_refill_time         0.165131  0.188904  0.205135
# pain                          0.276427 -0.049461  0.272051
# peristalsis                  -0.148574  0.118991 -0.149742
# abdominal_distention         -0.149064 -0.041589 -0.082973
# nasogastric_tube              0.023299 -0.055263 -0.013265
# nasogastric_reflux           -0.211128 -0.037006 -0.183108
# rectal_exam_feces            -0.199348  0.136169 -0.281696
# abdomen                      -0.316903  0.115729 -0.217630
# packed_cell_volume            0.163993  0.134179  0.204697
# total_protein                -0.113224 -0.124887 -0.108678
# outcome                      -0.332933 -0.098297 -0.271305
# surgical_lesion               1.000000 -0.007518  0.574441
# NH                           -0.007518  1.000000 -0.045643
# TL                            0.574441 -0.045643  1.000000
#
# [22 rows x 22 columns]

# %%
plt.figure(figsize=(20,20))
g=sns.heatmap(dataset.corr(), annot=True, cmap="RdYlGn")

# %%
# Tenemos dos variables muy correlacionadas, surgical_lesion y surgery
# Nos quedamos con surgical_lesion porque es la que está más correlacionada con la variable objetivo que es outcome
dataset_cor = dataset.drop(['surgery'], axis=1)
dataset_cor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   age                    299 non-null    int64
#  1   rectal_temp            299 non-null    float64
#  2   pulse                  299 non-null    float64
#  3   respiratory_rate       299 non-null    float64
#  4   temp_of_extremities    299 non-null    int8
#  5   peripheral_pulse       299 non-null    int8
#  6   mucous_membrane        299 non-null    int8
#  7   capillary_refill_time  299 non-null    int8
#  8   pain                   299 non-null    int8
#  9   peristalsis            299 non-null    int8
#  10  abdominal_distention   299 non-null    int8
#  11  nasogastric_tube       299 non-null    int8
#  12  nasogastric_reflux     299 non-null    int8
#  13  rectal_exam_feces      299 non-null    int8
#  14  abdomen                299 non-null    int8
#  15  packed_cell_volume     299 non-null    float64
#  16  total_protein          299 non-null    float64
#  17  outcome                299 non-null    int8
#  18  surgical_lesion        299 non-null    int64
#  19  NH                     299 non-null    int64
#  20  TL                     299 non-null    int64
# dtypes: float64(5), int64(4), int8(12)
# memory usage: 24.7 KB

# %%
correlaciones = abs(dataset_cor.corr()['outcome']).sort_values(ascending=False)
print (correlaciones)
# Out:
# outcome                  1.000000
# packed_cell_volume       0.401140
# pulse                    0.344670
# surgical_lesion          0.332933
# temp_of_extremities      0.290367
# TL                       0.271305
# capillary_refill_time    0.256294
# total_protein            0.245657
# abdomen                  0.214875
# rectal_exam_feces        0.193004
# nasogastric_reflux       0.181422
# peristalsis              0.165844
# peripheral_pulse         0.165719
# pain                     0.161964
# abdominal_distention     0.112309
# age                      0.101782
# NH                       0.098297
# respiratory_rate         0.079408
# mucous_membrane          0.056852
# nasogastric_tube         0.049156
# rectal_temp              0.006008
# Name: outcome, dtype: float64

# %%
# En este caso eliminaremos aquellos atributos que tengan una correlación inferior a 0.1

for col in range(len(correlaciones)):
  if abs(correlaciones[col]) < 0.1:
    dataset_cor = dataset_cor.drop([correlaciones.index[col]], axis=1)
# Out:
# <ipython-input-151-3438d414dfb8>:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if abs(correlaciones[col]) < 0.1:
# <ipython-input-151-3438d414dfb8>:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if abs(correlaciones[col]) < 0.1:
# <ipython-input-151-3438d414dfb8>:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if abs(correlaciones[col]) < 0.1:
# <ipython-input-151-3438d414dfb8>:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if abs(correlaciones[col]) < 0.1:
# <ipython-input-151-3438d414dfb8>:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if abs(correlaciones[col]) < 0.1:

# %%
dataset_cor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   age                    299 non-null    int64
#  1   pulse                  299 non-null    float64
#  2   temp_of_extremities    299 non-null    int8
#  3   peripheral_pulse       299 non-null    int8
#  4   capillary_refill_time  299 non-null    int8
#  5   pain                   299 non-null    int8
#  6   peristalsis            299 non-null    int8
#  7   abdominal_distention   299 non-null    int8
#  8   nasogastric_reflux     299 non-null    int8
#  9   rectal_exam_feces      299 non-null    int8
#  10  abdomen                299 non-null    int8
#  11  packed_cell_volume     299 non-null    float64
#  12  total_protein          299 non-null    float64
#  13  outcome                299 non-null    int8
#  14  surgical_lesion        299 non-null    int64
#  15  TL                     299 non-null    int64
# dtypes: float64(3), int64(3), int8(10)
# memory usage: 17.1 KB

# %% [markdown]
# #**Backward elimination**

# %%
import statsmodels.api as sm

X = dataset
y = dataset["outcome"]
dataset.head()
# Out:
#    surgery  age  rectal_temp  pulse  respiratory_rate  temp_of_extremities  \
# 0        0    1         38.5   66.0              28.0                    1
# 1        1    1         39.2   88.0              20.0                    1
# 2        0    1         38.3   40.0              24.0                    2
# 3        1    0         39.1  164.0              84.0                    0
# 4        0    1         37.3  104.0              35.0                    1
#
#    peripheral_pulse  mucous_membrane  capillary_refill_time  pain  ...  \
# 0                 3                3                      2     2  ...
# 1                 2                4                      1     3  ...
# 2                 2                5                      1     3  ...
# 3                 2                2                      2     1  ...
# 4                 2                2                      2     3  ...
#
#    nasogastric_tube  nasogastric_reflux  rectal_exam_feces  abdomen  \
# 0                 2                   2                  1        0
# 1                 2                   2                  0        4
# 2                 2                   2                  3        3
# 3                 0                   0                  1        0
# 4                 2                   2                  0        0
#
#    packed_cell_volume  total_protein  outcome  surgical_lesion  NH  TL
# 0                45.0            8.4        0                0   1   1
# 1                50.0           85.0        1                0   1   1
# 2                33.0            6.7        2                0   1   0
# 3                48.0            7.2        0                1   1   1
# 4                74.0            7.4        0                0   1   1
#
# [5 rows x 22 columns]

# %%
cols = list(X.columns)
pmax = 1
while (len(cols)>0):
    p= []
    X_1 = X[cols]
    X_1 = sm.add_constant(X_1)
    model = sm.OLS(y,X_1).fit()
    p = pd.Series(model.pvalues.values[1:],index = cols)
    pmax = max(p)
    feature_with_p_max = p.idxmax()
    if(pmax>0.05):
        cols.remove(feature_with_p_max)
    else:
        break
selected_features_BE = cols
print(selected_features_BE)
# Out:
# ['respiratory_rate', 'packed_cell_volume', 'outcome']

# %% [markdown]
# #**PCA 1**

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Normalizamos los datos
scaler=StandardScaler()
df = dataset.drop(['outcome'], axis=1) # quito la variable dependiente "Y"
scaler.fit(df)
X_scaled=scaler.transform(df)

# %%
# Instanciamos PCA
pca=PCA(n_components=15)
pca.fit(X_scaled) # obtener los componentes principales
X_pca=pca.transform(X_scaled) # convertimos nuestros datos con las nuevas dimensiones de PCA

# %%
print("shape of X_pca", X_pca.shape)
expl = pca.explained_variance_ratio_
print(expl)
print('suma:',sum(expl[0:14]))
# Out:
# shape of X_pca (299, 15)
# [0.17757224 0.08910713 0.08725603 0.06419146 0.05619663 0.05400979
#  0.05021534 0.04681304 0.04502049 0.04112419 0.03926549 0.03501817
#  0.03335955 0.03248361 0.02931895]
# suma: 0.8516331536615069

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %% [markdown]
# #**PCA 2**

# %%
dataset.keys()
# Out:
# Index(['surgery', 'age', 'rectal_temp', 'pulse', 'respiratory_rate',
#        'temp_of_extremities', 'peripheral_pulse', 'mucous_membrane',
#        'capillary_refill_time', 'pain', 'peristalsis', 'abdominal_distention',
#        'nasogastric_tube', 'nasogastric_reflux', 'rectal_exam_feces',
#        'abdomen', 'packed_cell_volume', 'total_protein', 'outcome',
#        'surgical_lesion', 'NH', 'TL'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
df = dataset.drop(['outcome'], axis=1) # quito la variable dependiente "Y"
scaler.fit(df)
scaled_data=scaler.transform(df)
scaled_data
# Out:
# array([[-1.22988009,  0.29541958,  0.44701045, ..., -1.32027242,
#         -0.34619386,  0.36357377],
#        [ 0.81308739,  0.29541958,  1.46840005, ..., -1.32027242,
#         -0.34619386,  0.36357377],
#        [-1.22988009,  0.29541958,  0.15518485, ..., -1.32027242,
#         -0.34619386, -1.90118784],
#        ...,
#        [ 0.81308739,  0.29541958, -1.01211755, ...,  0.75741944,
#         -0.34619386,  0.36357377],
#        [ 0.81308739,  0.29541958, -2.47124554, ...,  0.75741944,
#         -0.34619386,  0.36357377],
#        [ 0.81308739,  0.29541958, -1.44985594, ..., -1.32027242,
#         -0.34619386,  0.36357377]])

# %%
from sklearn.decomposition import PCA

pca=PCA(n_components=2)
pca.fit(scaled_data)
x_pca=pca.transform(scaled_data)

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=dataset['outcome'])
plt.xlabel('First principle component')
plt.ylabel('Second principle component')
# Out:
# Text(0, 0.5, 'Second principle component')
